# %% [markdown]
# # Introduction

# %% [markdown]
# The process to annotate a text using one of the CRF models trained for the "Gelehrtenkorrespondenz" DFG project is articulated in the following steps:
#
# 1. Preprocess, which includes:
#     * sentence tokenization
#     * Part-Of-Speech tagging and lemmatization
# 2. Feature extraction
# 3. Annotation

# %% [markdown]
# What you need:
# * Python 3
# * Scikit learn
# * NLTK
# * TreeTagger and a Python TreeTagger wrapper

# %%
import nltk
import os
import pickle
import sys

# %%
sys.path.append("../")

# %%
from training import load_dictionaries
from templates import template1
from training import InstanceFeatureExtractor
# Out:
# /Users/fmambrini/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/fmambrini/anaconda/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
text = '''1847 kehrte Mommsen nach Deutschland zurück, musste vorerst aber wieder als Lehrer arbeiten. 
Während der Märzrevolution von 1848 wurde er Journalist in Rendsburg und vertrat energisch seine liberalen Überzeugungen. 
Im Herbst dieses Jahres erhielt er einen Ruf als außerordentlicher Professor für Rechtswissenschaft nach Leipzig und konnte so endlich die wissenschaftliche Laufbahn einschlagen. 
Er begann eine umfangreiche Publikationstätigkeit, blieb aber auch politisch aktiv, zusammen mit seinen Freunden und Professorenkollegen Moriz Haupt und Otto Jahn. Wegen ihrer Beteiligung am sächsischen Maiaufstand 1849 wurden die drei angeklagt und 1851 aus dem Hochschuldienst entlassen. 
Mommsen wurde noch im selben Jahr auf einen Lehrstuhl für Römisches Recht in Zürich berufen, den er 1852 antrat. Hier fühlte er sich jedoch sehr unwohl; er klagte in einem Brief über die Schweizer: „Die gehören zum Froschgeschlecht, und man muss Gott danken, wenn sie Hochdeutsch sprechen und eine Serviette auf den Tisch legen.“ Er wollte daher gern nach Deutschland zurückkehren und folgte 1854 einer Berufung nach Breslau, wo er mit dem Privatdozenten Jacob Bernays Freundschaft schloss. 1856 verlieh ihm die Philosophische Fakultät der Universität Greifswald die Ehrendoktorwürde. Allerdings gefiel Mommsen auch Breslau nicht; vor allem stießen ihn die dortigen Studenten ab: „Die meisten stinken, alle sind faul“'''

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Sentence tokenization

# %% [markdown]
# We use the German Punkt tokenizer that was trained on the iDAI Publication data set. Download it from [here]()

# %%
tok_path = '/Users/fmambrini/PycharmProjects/iDAIPublications/idai_journals/lib/nltk_data_extension/tokenizers/punkt/PY3/dai_german_punkt.pickle'

# %%
tokenizer = nltk.data.load(tok_path)
sents = tokenizer.tokenize(text)

# %% [markdown]
# ## POS tagging and lemmatization

# %%
from treetagger import TreeTagger

# %%
tagged_sents = []
tt = TreeTagger(language='german')

for i, s in enumerate(sents):
    tags = tt.tag(s)
    tags = [tuple(tag + ["_", ""]) for tag in tags]
    tagged_sents.append(tags)

# %%
tagged_sents[0]
# Out:
# [('1847', 'CARD', '@card@', '_', ''),
#  ('kehrte', 'VVFIN', 'kehren', '_', ''),
#  ('Mommsen', 'NN', '<unknown>', '_', ''),
#  ('nach', 'APPR', 'nach', '_', ''),
#  ('Deutschland', 'NE', 'Deutschland', '_', ''),
#  ('zurück', 'PTKVZ', 'zurück', '_', ''),
#  (',', '$,', ',', '_', ''),
#  ('musste', 'VMFIN', 'müssen', '_', ''),
#  ('vorerst', 'ADV', 'vorerst', '_', ''),
#  ('aber', 'ADV', 'aber', '_', ''),
#  ('wieder', 'ADV', 'wieder', '_', ''),
#  ('als', 'KOKOM', 'als', '_', ''),
#  ('Lehrer', 'NN', 'Lehrer', '_', ''),
#  ('arbeiten', 'VVINF', 'arbeiten', '_', ''),
#  ('.', '$.', '.', '_', '')]

# %% [markdown]
# ## Load the model

# %%
model_path = "../lib/models/korrespondez_model_stage3.pickle"

# %%
with open(model_path, 'rb') as f:
    crf = pickle.load(f)

# %% [markdown]
# # Feature extraction

# %% [markdown]
# ## Load the dictionaries (places and persons)

# %%
d = {
    "persons": "../lib/dictionaries/persons.txt",
    "places": "../lib/dictionaries/places.txt"
  }

dicts = load_dictionaries(d)

# %%
dicts["persons"]
# Out:
# ['Abate',
#  'Pasquale',
#  'Abeken',
#  'Abeken',
#  'Heinrich',
#  'Abeken',
#  'Abeken',
#  'Wilhelm',
#  'Acerbi',
#  'Ackner',
#  'Adam',
#  'Frederick',
#  'Adda',
#  'Girolamo',
#  'Adilardi',
#  'Francesco',
#  'Adler',
#  'Friedrich',
#  'Adorni',
#  'Aegidi',
#  'Aglietti',
#  'Filippo',
#  'Agostini',
#  'Giosuè',
#  'Ainsley',
#  'James',
#  'Alacevich',
#  'Giuseppe',
#  'Albiciri',
#  'Cesare',
#  'Albon',
#  'Castillo',
#  'Aldehoven',
#  'Carl',
#  'Aldini',
#  'Pier Vittorio',
#  'Alessi',
#  'Giuseppe',
#  'Almer',
#  'Aloe',
#  'Stanislao',
#  'Alten',
#  'Althoff',
#  'Alvarez',
#  'Anibal',
#  'Amarelli',
#  'Vincenzio',
#  'Amari',
#  'Amati',
#  'Girolamo',
#  'Ambrosch',
#  'Julius Athanasius',
#  'Ambrosi',
#  'Ambrosio',
#  'Vincenzo',
#  'Amedei',
#  'Amelung',
#  'Walter',
#  'Ammendola',
#  'Giuseppe',
#  'Ancona',
#  'Amilcare',
#  'Andrea',
#  'Angelucci',
#  'Giulio-Anastasio',
#  'Angeluzzi',
#  'Giuseppe',
#  'Anglona',
#  'Ankershofen',
#  'Anselmi',
#  'Ansidei',
#  'Antaldi',
#  'Antici-Mattei',
#  'Antini',
#  'Giuseppe',
#  'Antonelli',
#  'Agostino',
#  'Antonelli',
#  'Giuseppe',
#  'Antonis',
#  'Antonisi',
#  'Cesare',
#  'Appel',
#  'Appelius',
#  'Christian Appelius',
#  'Josef',
#  'Apponyi',
#  'Alexander',
#  'Archini',
#  'Francesco',
#  'Arco',
#  'Carlo',
#  'Arditi',
#  'Michele',
#  'Arduini',
#  'Carlo',
#  'Arduser',
#  'Arezzo',
#  'Gioacchino Maria',
#  'Arganti',
#  'Antonio Vincenzo',
#  'Ariani',
#  'Felice',
#  'Aristarchi',
#  'Staurace',
#  'Armellini',
#  'Arneth',
#  'Joseph',
#  'Arnim-Suckow',
#  'Harry Kurt Eduard Carl',
#  'Arnold',
#  'Bernhard',
#  'Arnold',
#  'Lorenz',
#  'Arnoldi',
#  'Arnoult',
#  'Eugène',
#  'Arseniew',
#  'Asbach',
#  'Julius',
#  'Ascher',
#  'Ascoli',
#  'Asher',
#  'Aspeitia',
#  'Aube',
#  'Avellino',
#  'Avellino',
#  'Francesco Maria',
#  'Avolio',
#  'Fracesco',
#  'Avvolta',
#  'Carlo',
#  'Bacchetti',
#  'Ernesto',
#  'Bach',
#  'Bachofen',
#  'Johann Jakob',
#  'Bader',
#  'Baedeker',
#  'Fritz',
#  'Baensch',
#  'Wilhelm',
#  'Baer',
#  'Joseph',
#  'Baffanelli',
#  'Gaetano',
#  'Baffanelli',
#  'Luigi',
#  'Baggs',
#  'Carlo',
#  'Baglioni',
#  'Benedetto',
#  'Bagnolesi',
#  'Paride',
#  'Baiter',
#  'J. Baldelli',
#  'Ulisse',
#  'Balduzzi',
#  'Luigi',
#  'Ballerini',
#  'Aurelio',
#  'Ballotti',
#  'Pasquale',
#  'Benedetto',
#  'Baltard',
#  'Baluffi',
#  'Giacomo',
#  'Banchi',
#  'Bandinel',
#  'Banfield',
#  'Thomas',
#  'Bange',
#  'Barba',
#  'Emanuele',
#  'Barberi',
#  'Barberi',
#  'Tito',
#  'Barbetti',
#  'Bernardino',
#  'Barbini',
#  'Agostino',
#  'Bardelli',
#  'Bardez',
#  'Alexius',
#  'Bargigli',
#  'Angiolo',
#  'Barone',
#  'Raffaele',
#  'Barone',
#  'Vincenzo',
#  'Barracco',
#  'Giovanni',
#  'Johann',
#  'Barry',
#  'Bartels',
#  'Enno',
#  'Barth',
#  'Heinrich',
#  'Barth',
#  'Johann Ambrosius',
#  'Barthelemy',
#  'Natale',
#  'Bartlett',
#  'John',
#  'Bartoccini',
#  'Bartolomeo',
#  'Bartoccini',
#  'Marianna',
#  'Bartoli-Avveduti',
#  'Giulio',
#  'Bartolini',
#  'Bernardino',
#  'Bartolini',
#  'Luigi',
#  'Barzilai',
#  'Luigi',
#  'Basile',
#  'Salvatore',
#  'Bassel',
#  'Bassone',
#  'Cipriano',
#  'Baumann',
#  'Baumbach',
#  'Bazin',
#  'Bazzichelli',
#  'Giosafat',
#  'Becker',
#  'Carl Leonhard',
#  'Becker',
#  'Jakob',
#  'Becker',
#  'Paul',
#  'Becker',
#  'Wilhelm Adolf',
#  'Befani',
#  'Begni',
#  'Behrnauer',
#  'Belger',
#  'Christian',
#  'Belgrano',
#  'Bellermann',
#  'Belli',
#  'Francesco',
#  'Bellotti',
#  'Pasquale Benedetto',
#  'Bellotti',
#  'Pietro',
#  'Belmonte',
#  'Giuseppe',
#  'Beloch',
#  'Julius',
#  'Benfatti',
#  'Luigi',
#  'Beni',
#  'Girolamo',
#  'Benndorf',
#  'Otto',
#  'Benvenuti',
#  'Benvenuti',
#  'Leopoldo (Leo)',
#  'Berard',
#  'Berck',
#  'TBerduscheck',
#  'Moritz',
#  'Beretta',
#  'Giuseppe',
#  'Bergau',
#  'Berge',
#  'Bergman',
#  'Bergmann',
#  'Bergmann',
#  'Joseph',
#  'Bergonzoli',
#  'Paolo',
#  'Berlanga',
#  'Manuel Bernardi-Cassi',
#  'GheBernardini',
#  'Dario',
#  'Bernays',
#  'Jacob',
#  'Bernhardt',
#  'Bernoulli',
#  'Johann Jacob',
#  'Bernuth',
#  'Bertanza',
#  'Enrico',
#  'Bertinelli',
#  'Gaetano',
#  'Bertoldi',
#  'Bertolini',
#  'Dario',
#  'Bertolotti',
#  'Betham',
#  'Bethmann',
#  'Bethmann-Hollweg',
#  'Betti',
#  'Enrico',
#  'Betti',
#  'Salvatore',
#  'Bettio',
#  'Betton',
#  'Ch. Betz',
#  'Beuf',
#  'Luigi',
#  'Beugnot',
#  'Beverley',
#  'Bezold',
#  'Biadega',
#  'Giuseppe',
#  'Biagi',
#  'Guido',
#  'Biagioli',
#  'Clemente',
#  'Bianchi',
#  'Angelo Eliodoro',
#  'Bianchi',
#  'Filippo',
#  'Bianchi',
#  'Nicola',
#  'Bianchi',
#  'Pietro',
#  'Bianconi',
#  'Girolamo',
#  'Biehler',
#  'Bienkowski',
#  'Biepel',
#  'Billi',
#  'Alessandre',
#  'Biondelli',
#  'Bernardino',
#  'Biondi',
#  'Bioni',
#  'Luigi',
#  'Birch',
#  'Samuel',
#  'Bissolati',
#  'Stefano',
#  'Blacas',
#  'Pierre',
#  'Louis',
#  'Jean',
#  'Casimir',
#  'Blair',
#  'Robert',
#  'Blanc',
#  'Edmond',
#  'Blanchere',
#  'M.Blanco',
#  'Lorenzo',
#  'Blaserna',
#  'Blau',
#  'Blayes',
#  'Blazo',
#  'Antonios',
#  'Blessig',
#  'Blondel',
#  'Blondel',
#  'Blouet',
#  'Blume',
#  'Bluemner',
#  'Bocca',
#  'Boccardini',
#  'Giona',
#  'Bocchi',
#  'Benvenuto',
#  'Bocchi',
#  'Francesco',
#  'Antonio',
#  'Boeckh',
#  'August',
#  'Bode',
#  'Wilhelm',
#  'Boetticher',
#  'Boehm',
#  'Boehme',
#  'Albrecht',
#  'Bohn',
#  'Boileau',
#  'Boirin',
#  'Boisseoain',
#  'Boisserée',
#  'Sulpiz',
#  'Boissier',
#  'Gaston',
#  'Boix',
#  'Vincente',
#  'Bonamancia',
#  'Agostino',
#  'Bonanni',
#  'Daniele',
#  'Bonarelli',
#  'Giulio',
#  'Boncompagni',
#  'Baldassare',
#  'Boncompagni',
#  'Rodolfo',
#  'Bonfatti',
#  'Luigi',
#  'Bonghi',
#  'Diego',
#  'Bonghi',
#  'Onofrio',
#  'Bonghi',
#  'Ruggero',
#  'Bonomi',
#  'Antonio',
#  'Bonomi',
#  'Giuseppe',
#  'Bonucci',
#  'Carlo',
#  'Boor',
#  'Borani',
#  'Giambattista',
#  'Borbone',
#  'Leopoldo',
#  'Bordier',
#  'Henri',
#  'Borelli',
#  'Borghese',
#  'Camillo',
#  'Borghese',
#  'Borghesi',
#  'Bartolomeo',
#  'Borgia',
#  'Cesare',
#  'Borgia',
#  'Pompeo',
#  'Bormann',
#  'Eugen',
#  'Boerner',
#  'Borsari',
#  'Luigi',
#  'Borselli',
#  'Ettore',
#  'Bortolotti',
#  'Pietro',
#  'Bosco',
#  'Pasquale',
#  'Bospitelli',
#  'Giosafat',
#  'Botkin',
#  'Peter',
#  'Botkin',
#  'Peter',
#  'Botkine',
#  'Michele',
#  'Boettiger',
#  'Boudet',
#  'Bourgeois-Maze',
#  'Bourges',
#  'Bourguignon',
#  'Bover',
#  'Joaquin Maria',
#  'Bovet',
#  'Boyesen',
#  'Peter',
#  'Boysen',
#  'Bracci',
#  'Emilio',
#  'Braghelli',
#  'Giovanni',
#  'Braghirolli',
#  'Wilhelm',
#  'Brambilla',
#  'Alessandro',
#  'Brancaleoni',
#  'Franco',
#  'Brandi',
#  'Brandis',
#  'Branteghem',
#  'Brassier',
#  'Braun',
#  'Anne',
#  'Braun',
#  'Emil',
#  'Braun',
#  'Bravo',
#  'Bremen',
#  'Brenvery',
#  'Bresslau',
#  'Brettkopf',
#  'Brignone',
#  'Brigola',
#  'Gaetano',
#  'Brilli',
#  'Lodovico',
#  'Brizi',
#  'Oreste',
#  'Brizio',
#  'Edoardo',
#  'Brockhaus',
#  'Brockhaus',
#  'Brockhaus',
#  'Heinrich',
#  'Brogi',
#  'Giovanni',
#  'Brogi',
#  'Giacomo',
#  'Broensted',
#  'Brucciani',
#  'Bruehl',
#  'Brun',
#  'Brunn',
#  'Heinrich',
#  'Brunn',
#  'Bruzza',
#  'Luigi',
#  'Bubeck',
#  'Wilhelm',
#  'Bucci',
#  'Costantino',
#  'Bucci',
#  'Donato',
#  'Bucci',
#  'Buecheler',
#  'Franz',
#  'Bucher',
#  'Bruno',
#  'Buchholz',
#  'Bugge',
#  'Sophus',
#  'Bunsen',
#  'Bunsen',
#  'Carl',
#  'Bunsen',
#  'Emilia',
#  'Bunsen',
#  'Georg',
#  'Burckhaardt',
#  'Jacob',
#  'Burgers',
#  'Richard',
#  'Burgon',
#  'Thomas',
#  'Burnouf',
#  'Emile',
#  'Bursian',
#  'Burtt',
#  'Joseph',
#  'Buscaroli',
#  'Luigi',
#  'Buselli',
#  'Ettore',
#  'Busiri',
#  'Andrea',
#  'Busmanti',
#  'Silvio',
#  'Buttaoni',
#  'Cades',
#  'Alessandro',
#  'Cades',
#  'Annunziata',
#  'Cades',
#  'Tommaso',
#  'Caetani',
#  'Michelangelo',
#  'Caetani',
#  'Onorato',
#  'Cailleux',
#  'Calabrese',
#  'Andrea',
#  'Calanca',
#  'Oreste',
#  'Calcabale',
#  'Giambattista',
#  'Calderari',
#  'Enrico',
#  'Calderoni',
#  'Giacomo',
#  'Califano',
#  'Pasquale',
#  'Calleffi',
#  'Pietro',
#  'Francesco',
#  'Calvary',
#  'Calvert',
#  'Charles',
#  'Calvert',
#  'Frank',
#  'Camera',
#  'Matteo',
#  'Camilli',
#  'Stefano',
#  'Campagnoni',
#  'Fausto',
#  'Campana',
#  'Giovanni',
#  'Pietro',
#  'Campanari',
#  'Carlo',
#  'Campanari',
#  'Domenico',
#  'Campanari',
#  'Secondiano',
#  'Campari',
#  'Campi',
#  'Giuseppe',
#  'Canina',
#  'Luigi',
#  'Canino',
#  'Carlo',
#  'Luciano',
#  'Canitz',
#  'Helen',
#  'Canitz',
#  'Carl',
#  'Friedrich',
#  'Canna',
#  'Giovanni',
#  'Cantu',
#  'Cesare',
#  'Cantucci',
#  'Cape',
#  'Celabro',
#  'Capece',
#  'Carlo',
#  'Capecelatro',
#  'Giuseppe',
#  'Capei',
#  'Pietro',
#  'Capialbi',
#  'Antonio',
#  'Capialbi',
#  'Vito',
#  'Capobianchi',
#  'Pietro',
#  'Capocelli',
#  'Alessandro',
#  'Caporale',
#  'Giambattista',
#  'Capranesi',
#  'Francesco',
#  'Caputi',
#  'Francesco Paolo',
#  'Cara',
#  'Alberto',
#  'Caraba',
#  'Ambrogio',
#  'Caraba',
#  'Gaetano',
#  'Carafa',
#  'Carlo',
#  'Carapanos',
#  'ConsCarattoli',
#  'Luigi',
#  'Carbone',
#  'Carderera',
#  'Valentin',
#  'Cardinali',
#  'Clemente',
#  'Cardinali',
#  'Luigi',
#  'Carducci',
#  'Gio.Battista',
#  'Carelli',
#  'Carfora',
#  'Aniello',
#  'Carfora',
#  'Carli',
#  'Romualdo',
#  'Carlisle',
#  'Nicholas',
#  'Carnevali',
#  'Raffaele',
#  'Carosi',
#  'Giovanni',
#  'Carpegna',
#  'Guido',
#  'Carrara',
#  'Carrera',
#  'Francesco',
#  'Carretti',
#  'Nicola',
#  'Casanova',
#  'Gio.Battista',
#  'Casati',
#  'Caskey',
#  'Caspary',
#  'Robert',
#  'Casrtomediano',
#  'Sigismondo',
#  'Cassis',
#  'Francesco',
#  'Leo',
#  'Cassitto',
#  'Federigo',
#  'Castelfranco',
#  'Castellane',
#  'Castellani',
#  'Agostino',
#  'Castellani',
#  'Alessandro',
#  'Castellani',
#  'Augusto',
#  'Castellani',
#  'Henriette',
#  'Castiglioni',
#  'Carlo',
#  'Casuccini',
#  'Francesco',
#  'Casuccini',
#  'Pietro',
#  'Casuccini',
#  'Carlo',
#  'Casuccini',
#  'Ottavio',
#  'Cataldi',
#  'Nicola',
#  'Catoir',
#  'Cattaneo',
#  'Gaetano',
#  'Cavallari',
#  'Saverio',
#  'Cavedoni',
#  'Celestino',
#  'Cavedoni',
#  'Venanzio',
#  'Cavi',
#  'Pietro',
#  'Cecca',
#  'Erasmo',
#  'Ceccarelli',
#  'Pietro',
#  'Cecchini',
#  'Paolo',
#  'Cecconi',
#  'Giosuè',
#  'Ceccotti',
#  'Luca',
#  'Ceci',
#  'Antonio',
#  'Celesia',
#  'Emanuele',
#  'Cellini',
#  'Cesare',
#  'Cendrier',
#  'Cerroti',
#  'Francesco',
#  'Cerroti',
#  'Giovanni',
#  'Cervelli',
#  'Angelo-Antonio',
#  'Cesnola',
#  'Ceulenez',
#  'Adolf',
#  'Chabert',
#  'Chabouillet',
#  'Chartrouse',
#  'Charvet',
#  'Chaudes',
#  'Chellini',
#  'Alessandro',
#  'Chenaud',
#  'Chenue',
#  'Cherbonneau',
#  'Cherubino',
#  'Chiappelli',
#  'Alberto',
#  'Chiappelli',
#  'Alessandro',
#  'Chiellini',
#  'Enrico',
#  'Chierici',
#  'Gaetano',
#  'Chigi',
#  'Bonaventura',
#  'Chigi',
#  'Mario',
#  'Christ',
#  'Wilhelm',
#  'Ciamician',
#  'Giacomo Ciampi',
#  'Sebastiano',
#  'Ciccolini',
#  'Ottaviano',
#  'Cicerchia',
#  'Pietro',
#  'Cicerchia',
#  'Vincenzo',
#  'Cigalla',
#  'Giuseppe',
#  'Cinci',
#  'Annibale',
#  'Cinci',
#  'Giusto',
#  'Cinci',
#  'Vincenzo',
#  'Ciparini',
#  'Cipriani',
#  'Claasen',
#  'Clarac',
#  'Clarkes',
#  'Clasen',
#  'Christian',
#  'Clason',
#  'Octavius',
#  'Clayton',
#  'Clayton',
#  'John',
#  'Clement',
#  'Clermont',
#  'Cluever',
#  'Cochet',
#  'Coco',
#  'Giuseppe',
#  'Colonna',
#  'Colonna',
#  'FerColonna',
#  'Gioacchino',
#  'Colucci',
#  'Colucci',
#  'Colucci',
#  'Giuseppe',
#  'Colvin',
#  'Sidney',
#  'Comarmond',
#  'Commeter',
#  'Compagnoni',
#  'Battista',
#  'Comparetti',
#  'Domenico',
#  'Conestabile',
#  'Carlo',
#  'Conestabile',
#  'Giancarlo',
#  'Conestabile',
#  'Francesco',
#  'Conestabile',
#  'Scipione',
#  'Consano',
#  'Conze',
#  'Alexander',
#  'Contigliozzi',
#  'Coppi',
#  'Francesco',
#  'Corazzini',
#  'Francesco',
#  'Cordenons',
#  'Federico',
#  'Cornu',
#  'SeCorrenti',
#  'Cesare',
#  'Corsale',
#  'Domenico',
#  'Corssen',
#  'Julius',
#  'Corssen',
#  'Peter',
#  'Corssen',
#  'Cortese',
#  'Michele',
#  'Cortesi',
#  'Costa',
#  'Annibale',
#  'Costanti',
#  'Enrico',
#  'Costanzi',
#  'Coste',
#  'Cotini',
#  'Vincenzo',
#  'Cotta',
#  'Cozza',
#  'Adolfo',
#  'Cramer',
#  'Crawford',
#  'Cremona',
#  'Cremonese',
#  'Francesco',
#  'Crespellani',
#  'Argenio',
#  'Crespellani',
#  'Remigio',
#  'Crespi',
#  'Vincenzo',
#  'Creuzer',
#  'Friedrich',
#  'Criscio',
#  'Giuseppe',
#  'Cristofani',
#  'Antonio',
#  'Cubieres',
#  'Cucito',
#  'Giuseppe',
#  'Cuq',
#  'Curtius',
#  'Ernst',
#  'Czaeki',
#  'Felix',
#  'Daddi',
#  'Domenico',
#  'Dampiere',
#  'Dasti',
#  'Luigi',
#  'Daumet',
#  'Davis',
#  'J. Barnarel',
#  'Decharmes',
#  'Deecke',
#  'Wilhelm',
#  'Degen',
#  'Heinrich',
#  'Dei',
#  'Francesco',
#  'Luigi',
#  'Delbrueck',
#  'Richard',
#  'Delius',
#  'Nicolaus',
#  'Dennis',
#  'Geo',
#  'Depoletti',
#  'Alessandro',
#  'Depoletti',
#  'Francesco',
#  'Depoletti',
#  'Derenthall',
#  'Dernburg',
#  'Dernburg',
#  'Heinrich',
#  'Desantis',
#  'Venceslao',
#  'Descemet',
#  'Desjardins',
#  'Abel',
#  'Desjardins',
#  'Ernest',
#  'Desplaces',
#  'Dessau',
#  'Hermann',
#  'Detlefsen',
#  'Diamilla',
#  'Demetrio',
#  'Didier',
#  'Didot',
#  'Alfred',
#  'Dielitz',
#  'Dietrichstein',
#  'Moritz',
#  'Dietz',
#  'JoDilthey',
#  'Karl',
#  'Dini',
#  'Bartolommeo',
#  'Dino',
#  'Salvatore',
#  'Dodwell',
#  'Domaszewski',
#  'Dominicis',
#  'Franco',
#  'Donner',
#  'Otto',
#  'Doria',
#  'Simmaco',
#  'Doering',
#  'Wilhelm',
#  'Doerpfeld',
#  'Wilhelm',
#  'Dragendorff',
#  'Hans',
#  'Dragomanni',
#  'Francesco',
#  'Dragonetti',
#  'Luigi',
#  'Dressel',
#  'Dressel',
#  'Albert',
#  'Dressel',
#  'Heinrich',
#  'Droysen',
#  'Gustaf',
#  'Dubois',
#  'Duhn',
#  'Friedrich',
#  'Duemichen',
#  'Johannes',
#  'Duemmler',
#  'Ernst',
#  'Duemmler',
#  'Ferdinand',
#  'Dumon',
#  'Durand',
#  'Durand',
#  'Dureau',
#  'Duetschke',
#  'Hans',
#  'Duvinage',
#  'Dyer',
#  'Ebers',
#  'Georg',
#  'Eberz',
#  'Anton',
#  'Ebhardt',
#  'Giusto',
#  'Ebner',
#  'Egg',
#  'Giacomo',
#  'Egger',
#  'Egger',
#  'Max',
#  'Egger',
#  ...]

# %% [markdown]
# ## Run the feature extractor

# %%
ext = InstanceFeatureExtractor(tagged_sents, dicts)

# %%
# %%time
X_anno = ext.extract_features(template1)
# Out:
# CPU times: user 19.8 ms, sys: 1.33 ms, total: 21.1 ms
# Wall time: 20.7 ms

# %%
X_anno[0]
# Out:
# [{'BOS': 'True',
#   'endsWithDigit[0]': 'True',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[0]': 'True',
#   'hasDigit[1]': 'False',
#   'isDigit[0]': 'True',
#   'isDigit[1]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'True',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[0]': '@card@',
#   'lemma[1]': 'kehren',
#   'pos[0]': 'CARD',
#   'pos[0]|pos[1]': 'CARD|VVFIN',
#   'pos[0]|pos[1]|pos[2]': 'CARD|VVFIN|NN',
#   'pos[1]': 'VVFIN',
#   'pos[1]|pos[2]': 'VVFIN|NN',
#   'pos[2]': 'NN',
#   'prefix_long[0]': '1847',
#   'prefix_long[1]': 'kehrt',
#   'prefix_long[2]': 'Momms',
#   'prefix_short[0]': '184',
#   'prefix_short[1]': 'keh',
#   'prefix_short[2]': 'Mom',
#   'rank[0]': '0',
#   'sent_rank[0]': '0',
#   'suffix_long[0]': '1847',
#   'suffix_long[0]|suffix_long[1]': '1847|hrte',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': '1847|hrte|msen',
#   'suffix_long[1]': 'hrte',
#   'suffix_long[2]': 'msen',
#   'suffix_short[0]': '47',
#   'suffix_short[0]|suffix_short[1]': '47|te',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': '47|te|en',
#   'suffix_short[1]': 'te',
#   'suffix_short[2]': 'en',
#   'w[0]': '1847',
#   'w[0]|w[1]': '1847|kehrte',
#   'w[1]': 'kehrte',
#   'w[2]': 'Mommsen',
#   'w_lower[0]': '1847',
#   'w_lower[1]': 'kehrte',
#   'w_lower[2]': 'mommsen'},
#  {'endsWithDigit[-1]': 'True',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'True',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'True',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'True',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'True',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': '@card@',
#   'lemma[0]': 'kehren',
#   'lemma[1]': '<unknown>',
#   'pos[-1]': 'CARD',
#   'pos[-1]|pos[0]': 'CARD|VVFIN',
#   'pos[-1]|pos[0]|pos[1]': 'CARD|VVFIN|NN',
#   'pos[0]': 'VVFIN',
#   'pos[0]|pos[1]': 'VVFIN|NN',
#   'pos[0]|pos[1]|pos[2]': 'VVFIN|NN|APPR',
#   'pos[1]': 'NN',
#   'pos[1]|pos[2]': 'NN|APPR',
#   'pos[2]': 'APPR',
#   'prefix_long[-1]': '1847',
#   'prefix_long[0]': 'kehrt',
#   'prefix_long[1]': 'Momms',
#   'prefix_long[2]': 'nach',
#   'prefix_short[-1]': '184',
#   'prefix_short[0]': 'keh',
#   'prefix_short[1]': 'Mom',
#   'prefix_short[2]': 'nac',
#   'rank[0]': '1',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': '1847',
#   'suffix_long[-1]|suffix_long[0]': '1847|hrte',
#   'suffix_long[0]': 'hrte',
#   'suffix_long[0]|suffix_long[1]': 'hrte|msen',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'hrte|msen|nach',
#   'suffix_long[1]': 'msen',
#   'suffix_long[2]': 'nach',
#   'suffix_short[-1]': '47',
#   'suffix_short[-1]|suffix_short[0]': '47|te',
#   'suffix_short[0]': 'te',
#   'suffix_short[0]|suffix_short[1]': 'te|en',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'te|en|ch',
#   'suffix_short[1]': 'en',
#   'suffix_short[2]': 'ch',
#   'w[-1]': '1847',
#   'w[-1]|w[0]': '1847|kehrte',
#   'w[0]': 'kehrte',
#   'w[0]|w[1]': 'kehrte|Mommsen',
#   'w[1]': 'Mommsen',
#   'w[2]': 'nach',
#   'w_lower[-1]': '1847',
#   'w_lower[0]': 'kehrte',
#   'w_lower[1]': 'mommsen',
#   'w_lower[2]': 'nach'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'True',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'True',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'kehren',
#   'lemma[0]': '<unknown>',
#   'lemma[1]': 'nach',
#   'pos[-1]': 'VVFIN',
#   'pos[-1]|pos[0]': 'VVFIN|NN',
#   'pos[-1]|pos[0]|pos[1]': 'VVFIN|NN|APPR',
#   'pos[-2]': 'CARD',
#   'pos[-2]|pos[-1]': 'CARD|VVFIN',
#   'pos[-2]|pos[-1]|pos[0]': 'CARD|VVFIN|NN',
#   'pos[0]': 'NN',
#   'pos[0]|pos[1]': 'NN|APPR',
#   'pos[0]|pos[1]|pos[2]': 'NN|APPR|NE',
#   'pos[1]': 'APPR',
#   'pos[1]|pos[2]': 'APPR|NE',
#   'pos[2]': 'NE',
#   'prefix_long[-1]': 'kehrt',
#   'prefix_long[-2]': '1847',
#   'prefix_long[0]': 'Momms',
#   'prefix_long[1]': 'nach',
#   'prefix_long[2]': 'Deuts',
#   'prefix_short[-1]': 'keh',
#   'prefix_short[-2]': '184',
#   'prefix_short[0]': 'Mom',
#   'prefix_short[1]': 'nac',
#   'prefix_short[2]': 'Deu',
#   'rank[0]': '2',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'hrte',
#   'suffix_long[-1]|suffix_long[0]': 'hrte|msen',
#   'suffix_long[-2]': '1847',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': '1847|hrte|msen',
#   'suffix_long[0]': 'msen',
#   'suffix_long[0]|suffix_long[1]': 'msen|nach',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'msen|nach|land',
#   'suffix_long[1]': 'nach',
#   'suffix_long[2]': 'land',
#   'suffix_short[-1]': 'te',
#   'suffix_short[-1]|suffix_short[0]': 'te|en',
#   'suffix_short[-2]': '47',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': '47|te|en',
#   'suffix_short[0]': 'en',
#   'suffix_short[0]|suffix_short[1]': 'en|ch',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'en|ch|nd',
#   'suffix_short[1]': 'ch',
#   'suffix_short[2]': 'nd',
#   'w[-1]': 'kehrte',
#   'w[-1]|w[0]': 'kehrte|Mommsen',
#   'w[-2]': '1847',
#   'w[0]': 'Mommsen',
#   'w[0]|w[1]': 'Mommsen|nach',
#   'w[1]': 'nach',
#   'w[2]': 'Deutschland',
#   'w_lower[-1]': 'kehrte',
#   'w_lower[-2]': '1847',
#   'w_lower[0]': 'mommsen',
#   'w_lower[1]': 'nach',
#   'w_lower[2]': 'deutschland'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'True',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'True',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'True',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': '<unknown>',
#   'lemma[0]': 'nach',
#   'lemma[1]': 'Deutschland',
#   'pos[-1]': 'NN',
#   'pos[-1]|pos[0]': 'NN|APPR',
#   'pos[-1]|pos[0]|pos[1]': 'NN|APPR|NE',
#   'pos[-2]': 'VVFIN',
#   'pos[-2]|pos[-1]': 'VVFIN|NN',
#   'pos[-2]|pos[-1]|pos[0]': 'VVFIN|NN|APPR',
#   'pos[0]': 'APPR',
#   'pos[0]|pos[1]': 'APPR|NE',
#   'pos[0]|pos[1]|pos[2]': 'APPR|NE|PTKVZ',
#   'pos[1]': 'NE',
#   'pos[1]|pos[2]': 'NE|PTKVZ',
#   'pos[2]': 'PTKVZ',
#   'prefix_long[-1]': 'Momms',
#   'prefix_long[-2]': 'kehrt',
#   'prefix_long[0]': 'nach',
#   'prefix_long[1]': 'Deuts',
#   'prefix_long[2]': 'zurüc',
#   'prefix_short[-1]': 'Mom',
#   'prefix_short[-2]': 'keh',
#   'prefix_short[0]': 'nac',
#   'prefix_short[1]': 'Deu',
#   'prefix_short[2]': 'zur',
#   'rank[0]': '3',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'msen',
#   'suffix_long[-1]|suffix_long[0]': 'msen|nach',
#   'suffix_long[-2]': 'hrte',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'hrte|msen|nach',
#   'suffix_long[0]': 'nach',
#   'suffix_long[0]|suffix_long[1]': 'nach|land',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'nach|land|rück',
#   'suffix_long[1]': 'land',
#   'suffix_long[2]': 'rück',
#   'suffix_short[-1]': 'en',
#   'suffix_short[-1]|suffix_short[0]': 'en|ch',
#   'suffix_short[-2]': 'te',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'te|en|ch',
#   'suffix_short[0]': 'ch',
#   'suffix_short[0]|suffix_short[1]': 'ch|nd',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'ch|nd|ck',
#   'suffix_short[1]': 'nd',
#   'suffix_short[2]': 'ck',
#   'w[-1]': 'Mommsen',
#   'w[-1]|w[0]': 'Mommsen|nach',
#   'w[-2]': 'kehrte',
#   'w[0]': 'nach',
#   'w[0]|w[1]': 'nach|Deutschland',
#   'w[1]': 'Deutschland',
#   'w[2]': 'zurück',
#   'w_lower[-1]': 'mommsen',
#   'w_lower[-2]': 'kehrte',
#   'w_lower[0]': 'nach',
#   'w_lower[1]': 'deutschland',
#   'w_lower[2]': 'zurück'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'True',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'True',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'nach',
#   'lemma[0]': 'Deutschland',
#   'lemma[1]': 'zurück',
#   'pos[-1]': 'APPR',
#   'pos[-1]|pos[0]': 'APPR|NE',
#   'pos[-1]|pos[0]|pos[1]': 'APPR|NE|PTKVZ',
#   'pos[-2]': 'NN',
#   'pos[-2]|pos[-1]': 'NN|APPR',
#   'pos[-2]|pos[-1]|pos[0]': 'NN|APPR|NE',
#   'pos[0]': 'NE',
#   'pos[0]|pos[1]': 'NE|PTKVZ',
#   'pos[0]|pos[1]|pos[2]': 'NE|PTKVZ|$,',
#   'pos[1]': 'PTKVZ',
#   'pos[1]|pos[2]': 'PTKVZ|$,',
#   'pos[2]': '$,',
#   'prefix_long[-1]': 'nach',
#   'prefix_long[-2]': 'Momms',
#   'prefix_long[0]': 'Deuts',
#   'prefix_long[1]': 'zurüc',
#   'prefix_long[2]': ',',
#   'prefix_short[-1]': 'nac',
#   'prefix_short[-2]': 'Mom',
#   'prefix_short[0]': 'Deu',
#   'prefix_short[1]': 'zur',
#   'prefix_short[2]': ',',
#   'rank[0]': '4',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'nach',
#   'suffix_long[-1]|suffix_long[0]': 'nach|land',
#   'suffix_long[-2]': 'msen',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'msen|nach|land',
#   'suffix_long[0]': 'land',
#   'suffix_long[0]|suffix_long[1]': 'land|rück',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'land|rück|,',
#   'suffix_long[1]': 'rück',
#   'suffix_long[2]': ',',
#   'suffix_short[-1]': 'ch',
#   'suffix_short[-1]|suffix_short[0]': 'ch|nd',
#   'suffix_short[-2]': 'en',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'en|ch|nd',
#   'suffix_short[0]': 'nd',
#   'suffix_short[0]|suffix_short[1]': 'nd|ck',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'nd|ck|,',
#   'suffix_short[1]': 'ck',
#   'suffix_short[2]': ',',
#   'w[-1]': 'nach',
#   'w[-1]|w[0]': 'nach|Deutschland',
#   'w[-2]': 'Mommsen',
#   'w[0]': 'Deutschland',
#   'w[0]|w[1]': 'Deutschland|zurück',
#   'w[1]': 'zurück',
#   'w[2]': ',',
#   'w_lower[-1]': 'nach',
#   'w_lower[-2]': 'mommsen',
#   'w_lower[0]': 'deutschland',
#   'w_lower[1]': 'zurück',
#   'w_lower[2]': ','},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'True',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'Deutschland',
#   'lemma[0]': 'zurück',
#   'lemma[1]': ',',
#   'pos[-1]': 'NE',
#   'pos[-1]|pos[0]': 'NE|PTKVZ',
#   'pos[-1]|pos[0]|pos[1]': 'NE|PTKVZ|$,',
#   'pos[-2]': 'APPR',
#   'pos[-2]|pos[-1]': 'APPR|NE',
#   'pos[-2]|pos[-1]|pos[0]': 'APPR|NE|PTKVZ',
#   'pos[0]': 'PTKVZ',
#   'pos[0]|pos[1]': 'PTKVZ|$,',
#   'pos[0]|pos[1]|pos[2]': 'PTKVZ|$,|VMFIN',
#   'pos[1]': '$,',
#   'pos[1]|pos[2]': '$,|VMFIN',
#   'pos[2]': 'VMFIN',
#   'prefix_long[-1]': 'Deuts',
#   'prefix_long[-2]': 'nach',
#   'prefix_long[0]': 'zurüc',
#   'prefix_long[1]': ',',
#   'prefix_long[2]': 'musst',
#   'prefix_short[-1]': 'Deu',
#   'prefix_short[-2]': 'nac',
#   'prefix_short[0]': 'zur',
#   'prefix_short[1]': ',',
#   'prefix_short[2]': 'mus',
#   'rank[0]': '5',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'land',
#   'suffix_long[-1]|suffix_long[0]': 'land|rück',
#   'suffix_long[-2]': 'nach',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'nach|land|rück',
#   'suffix_long[0]': 'rück',
#   'suffix_long[0]|suffix_long[1]': 'rück|,',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'rück|,|sste',
#   'suffix_long[1]': ',',
#   'suffix_long[2]': 'sste',
#   'suffix_short[-1]': 'nd',
#   'suffix_short[-1]|suffix_short[0]': 'nd|ck',
#   'suffix_short[-2]': 'ch',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'ch|nd|ck',
#   'suffix_short[0]': 'ck',
#   'suffix_short[0]|suffix_short[1]': 'ck|,',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'ck|,|te',
#   'suffix_short[1]': ',',
#   'suffix_short[2]': 'te',
#   'w[-1]': 'Deutschland',
#   'w[-1]|w[0]': 'Deutschland|zurück',
#   'w[-2]': 'nach',
#   'w[0]': 'zurück',
#   'w[0]|w[1]': 'zurück|,',
#   'w[1]': ',',
#   'w[2]': 'musste',
#   'w_lower[-1]': 'deutschland',
#   'w_lower[-2]': 'nach',
#   'w_lower[0]': 'zurück',
#   'w_lower[1]': ',',
#   'w_lower[2]': 'musste'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'zurück',
#   'lemma[0]': ',',
#   'lemma[1]': 'müssen',
#   'pos[-1]': 'PTKVZ',
#   'pos[-1]|pos[0]': 'PTKVZ|$,',
#   'pos[-1]|pos[0]|pos[1]': 'PTKVZ|$,|VMFIN',
#   'pos[-2]': 'NE',
#   'pos[-2]|pos[-1]': 'NE|PTKVZ',
#   'pos[-2]|pos[-1]|pos[0]': 'NE|PTKVZ|$,',
#   'pos[0]': '$,',
#   'pos[0]|pos[1]': '$,|VMFIN',
#   'pos[0]|pos[1]|pos[2]': '$,|VMFIN|ADV',
#   'pos[1]': 'VMFIN',
#   'pos[1]|pos[2]': 'VMFIN|ADV',
#   'pos[2]': 'ADV',
#   'prefix_long[-1]': 'zurüc',
#   'prefix_long[-2]': 'Deuts',
#   'prefix_long[0]': ',',
#   'prefix_long[1]': 'musst',
#   'prefix_long[2]': 'vorer',
#   'prefix_short[-1]': 'zur',
#   'prefix_short[-2]': 'Deu',
#   'prefix_short[0]': ',',
#   'prefix_short[1]': 'mus',
#   'prefix_short[2]': 'vor',
#   'rank[0]': '6',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'rück',
#   'suffix_long[-1]|suffix_long[0]': 'rück|,',
#   'suffix_long[-2]': 'land',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'land|rück|,',
#   'suffix_long[0]': ',',
#   'suffix_long[0]|suffix_long[1]': ',|sste',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': ',|sste|erst',
#   'suffix_long[1]': 'sste',
#   'suffix_long[2]': 'erst',
#   'suffix_short[-1]': 'ck',
#   'suffix_short[-1]|suffix_short[0]': 'ck|,',
#   'suffix_short[-2]': 'nd',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'nd|ck|,',
#   'suffix_short[0]': ',',
#   'suffix_short[0]|suffix_short[1]': ',|te',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': ',|te|st',
#   'suffix_short[1]': 'te',
#   'suffix_short[2]': 'st',
#   'w[-1]': 'zurück',
#   'w[-1]|w[0]': 'zurück|,',
#   'w[-2]': 'Deutschland',
#   'w[0]': ',',
#   'w[0]|w[1]': ',|musste',
#   'w[1]': 'musste',
#   'w[2]': 'vorerst',
#   'w_lower[-1]': 'zurück',
#   'w_lower[-2]': 'deutschland',
#   'w_lower[0]': ',',
#   'w_lower[1]': 'musste',
#   'w_lower[2]': 'vorerst'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': ',',
#   'lemma[0]': 'müssen',
#   'lemma[1]': 'vorerst',
#   'pos[-1]': '$,',
#   'pos[-1]|pos[0]': '$,|VMFIN',
#   'pos[-1]|pos[0]|pos[1]': '$,|VMFIN|ADV',
#   'pos[-2]': 'PTKVZ',
#   'pos[-2]|pos[-1]': 'PTKVZ|$,',
#   'pos[-2]|pos[-1]|pos[0]': 'PTKVZ|$,|VMFIN',
#   'pos[0]': 'VMFIN',
#   'pos[0]|pos[1]': 'VMFIN|ADV',
#   'pos[0]|pos[1]|pos[2]': 'VMFIN|ADV|ADV',
#   'pos[1]': 'ADV',
#   'pos[1]|pos[2]': 'ADV|ADV',
#   'pos[2]': 'ADV',
#   'prefix_long[-1]': ',',
#   'prefix_long[-2]': 'zurüc',
#   'prefix_long[0]': 'musst',
#   'prefix_long[1]': 'vorer',
#   'prefix_long[2]': 'aber',
#   'prefix_short[-1]': ',',
#   'prefix_short[-2]': 'zur',
#   'prefix_short[0]': 'mus',
#   'prefix_short[1]': 'vor',
#   'prefix_short[2]': 'abe',
#   'rank[0]': '7',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': ',',
#   'suffix_long[-1]|suffix_long[0]': ',|sste',
#   'suffix_long[-2]': 'rück',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'rück|,|sste',
#   'suffix_long[0]': 'sste',
#   'suffix_long[0]|suffix_long[1]': 'sste|erst',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'sste|erst|aber',
#   'suffix_long[1]': 'erst',
#   'suffix_long[2]': 'aber',
#   'suffix_short[-1]': ',',
#   'suffix_short[-1]|suffix_short[0]': ',|te',
#   'suffix_short[-2]': 'ck',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'ck|,|te',
#   'suffix_short[0]': 'te',
#   'suffix_short[0]|suffix_short[1]': 'te|st',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'te|st|er',
#   'suffix_short[1]': 'st',
#   'suffix_short[2]': 'er',
#   'w[-1]': ',',
#   'w[-1]|w[0]': ',|musste',
#   'w[-2]': 'zurück',
#   'w[0]': 'musste',
#   'w[0]|w[1]': 'musste|vorerst',
#   'w[1]': 'vorerst',
#   'w[2]': 'aber',
#   'w_lower[-1]': ',',
#   'w_lower[-2]': 'zurück',
#   'w_lower[0]': 'musste',
#   'w_lower[1]': 'vorerst',
#   'w_lower[2]': 'aber'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'müssen',
#   'lemma[0]': 'vorerst',
#   'lemma[1]': 'aber',
#   'pos[-1]': 'VMFIN',
#   'pos[-1]|pos[0]': 'VMFIN|ADV',
#   'pos[-1]|pos[0]|pos[1]': 'VMFIN|ADV|ADV',
#   'pos[-2]': '$,',
#   'pos[-2]|pos[-1]': '$,|VMFIN',
#   'pos[-2]|pos[-1]|pos[0]': '$,|VMFIN|ADV',
#   'pos[0]': 'ADV',
#   'pos[0]|pos[1]': 'ADV|ADV',
#   'pos[0]|pos[1]|pos[2]': 'ADV|ADV|ADV',
#   'pos[1]': 'ADV',
#   'pos[1]|pos[2]': 'ADV|ADV',
#   'pos[2]': 'ADV',
#   'prefix_long[-1]': 'musst',
#   'prefix_long[-2]': ',',
#   'prefix_long[0]': 'vorer',
#   'prefix_long[1]': 'aber',
#   'prefix_long[2]': 'wiede',
#   'prefix_short[-1]': 'mus',
#   'prefix_short[-2]': ',',
#   'prefix_short[0]': 'vor',
#   'prefix_short[1]': 'abe',
#   'prefix_short[2]': 'wie',
#   'rank[0]': '8',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'sste',
#   'suffix_long[-1]|suffix_long[0]': 'sste|erst',
#   'suffix_long[-2]': ',',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': ',|sste|erst',
#   'suffix_long[0]': 'erst',
#   'suffix_long[0]|suffix_long[1]': 'erst|aber',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'erst|aber|eder',
#   'suffix_long[1]': 'aber',
#   'suffix_long[2]': 'eder',
#   'suffix_short[-1]': 'te',
#   'suffix_short[-1]|suffix_short[0]': 'te|st',
#   'suffix_short[-2]': ',',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': ',|te|st',
#   'suffix_short[0]': 'st',
#   'suffix_short[0]|suffix_short[1]': 'st|er',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'st|er|er',
#   'suffix_short[1]': 'er',
#   'suffix_short[2]': 'er',
#   'w[-1]': 'musste',
#   'w[-1]|w[0]': 'musste|vorerst',
#   'w[-2]': ',',
#   'w[0]': 'vorerst',
#   'w[0]|w[1]': 'vorerst|aber',
#   'w[1]': 'aber',
#   'w[2]': 'wieder',
#   'w_lower[-1]': 'musste',
#   'w_lower[-2]': ',',
#   'w_lower[0]': 'vorerst',
#   'w_lower[1]': 'aber',
#   'w_lower[2]': 'wieder'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'vorerst',
#   'lemma[0]': 'aber',
#   'lemma[1]': 'wieder',
#   'pos[-1]': 'ADV',
#   'pos[-1]|pos[0]': 'ADV|ADV',
#   'pos[-1]|pos[0]|pos[1]': 'ADV|ADV|ADV',
#   'pos[-2]': 'VMFIN',
#   'pos[-2]|pos[-1]': 'VMFIN|ADV',
#   'pos[-2]|pos[-1]|pos[0]': 'VMFIN|ADV|ADV',
#   'pos[0]': 'ADV',
#   'pos[0]|pos[1]': 'ADV|ADV',
#   'pos[0]|pos[1]|pos[2]': 'ADV|ADV|KOKOM',
#   'pos[1]': 'ADV',
#   'pos[1]|pos[2]': 'ADV|KOKOM',
#   'pos[2]': 'KOKOM',
#   'prefix_long[-1]': 'vorer',
#   'prefix_long[-2]': 'musst',
#   'prefix_long[0]': 'aber',
#   'prefix_long[1]': 'wiede',
#   'prefix_long[2]': 'als',
#   'prefix_short[-1]': 'vor',
#   'prefix_short[-2]': 'mus',
#   'prefix_short[0]': 'abe',
#   'prefix_short[1]': 'wie',
#   'prefix_short[2]': 'als',
#   'rank[0]': '9',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'erst',
#   'suffix_long[-1]|suffix_long[0]': 'erst|aber',
#   'suffix_long[-2]': 'sste',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'sste|erst|aber',
#   'suffix_long[0]': 'aber',
#   'suffix_long[0]|suffix_long[1]': 'aber|eder',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'aber|eder|als',
#   'suffix_long[1]': 'eder',
#   'suffix_long[2]': 'als',
#   'suffix_short[-1]': 'st',
#   'suffix_short[-1]|suffix_short[0]': 'st|er',
#   'suffix_short[-2]': 'te',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'te|st|er',
#   'suffix_short[0]': 'er',
#   'suffix_short[0]|suffix_short[1]': 'er|er',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'er|er|ls',
#   'suffix_short[1]': 'er',
#   'suffix_short[2]': 'ls',
#   'w[-1]': 'vorerst',
#   'w[-1]|w[0]': 'vorerst|aber',
#   'w[-2]': 'musste',
#   'w[0]': 'aber',
#   'w[0]|w[1]': 'aber|wieder',
#   'w[1]': 'wieder',
#   'w[2]': 'als',
#   'w_lower[-1]': 'vorerst',
#   'w_lower[-2]': 'musste',
#   'w_lower[0]': 'aber',
#   'w_lower[1]': 'wieder',
#   'w_lower[2]': 'als'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'aber',
#   'lemma[0]': 'wieder',
#   'lemma[1]': 'als',
#   'pos[-1]': 'ADV',
#   'pos[-1]|pos[0]': 'ADV|ADV',
#   'pos[-1]|pos[0]|pos[1]': 'ADV|ADV|KOKOM',
#   'pos[-2]': 'ADV',
#   'pos[-2]|pos[-1]': 'ADV|ADV',
#   'pos[-2]|pos[-1]|pos[0]': 'ADV|ADV|ADV',
#   'pos[0]': 'ADV',
#   'pos[0]|pos[1]': 'ADV|KOKOM',
#   'pos[0]|pos[1]|pos[2]': 'ADV|KOKOM|NN',
#   'pos[1]': 'KOKOM',
#   'pos[1]|pos[2]': 'KOKOM|NN',
#   'pos[2]': 'NN',
#   'prefix_long[-1]': 'aber',
#   'prefix_long[-2]': 'vorer',
#   'prefix_long[0]': 'wiede',
#   'prefix_long[1]': 'als',
#   'prefix_long[2]': 'Lehre',
#   'prefix_short[-1]': 'abe',
#   'prefix_short[-2]': 'vor',
#   'prefix_short[0]': 'wie',
#   'prefix_short[1]': 'als',
#   'prefix_short[2]': 'Leh',
#   'rank[0]': '10',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'aber',
#   'suffix_long[-1]|suffix_long[0]': 'aber|eder',
#   'suffix_long[-2]': 'erst',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'erst|aber|eder',
#   'suffix_long[0]': 'eder',
#   'suffix_long[0]|suffix_long[1]': 'eder|als',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'eder|als|hrer',
#   'suffix_long[1]': 'als',
#   'suffix_long[2]': 'hrer',
#   'suffix_short[-1]': 'er',
#   'suffix_short[-1]|suffix_short[0]': 'er|er',
#   'suffix_short[-2]': 'st',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'st|er|er',
#   'suffix_short[0]': 'er',
#   'suffix_short[0]|suffix_short[1]': 'er|ls',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'er|ls|er',
#   'suffix_short[1]': 'ls',
#   'suffix_short[2]': 'er',
#   'w[-1]': 'aber',
#   'w[-1]|w[0]': 'aber|wieder',
#   'w[-2]': 'vorerst',
#   'w[0]': 'wieder',
#   'w[0]|w[1]': 'wieder|als',
#   'w[1]': 'als',
#   'w[2]': 'Lehrer',
#   'w_lower[-1]': 'aber',
#   'w_lower[-2]': 'vorerst',
#   'w_lower[0]': 'wieder',
#   'w_lower[1]': 'als',
#   'w_lower[2]': 'lehrer'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'True',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'wieder',
#   'lemma[0]': 'als',
#   'lemma[1]': 'Lehrer',
#   'pos[-1]': 'ADV',
#   'pos[-1]|pos[0]': 'ADV|KOKOM',
#   'pos[-1]|pos[0]|pos[1]': 'ADV|KOKOM|NN',
#   'pos[-2]': 'ADV',
#   'pos[-2]|pos[-1]': 'ADV|ADV',
#   'pos[-2]|pos[-1]|pos[0]': 'ADV|ADV|KOKOM',
#   'pos[0]': 'KOKOM',
#   'pos[0]|pos[1]': 'KOKOM|NN',
#   'pos[0]|pos[1]|pos[2]': 'KOKOM|NN|VVINF',
#   'pos[1]': 'NN',
#   'pos[1]|pos[2]': 'NN|VVINF',
#   'pos[2]': 'VVINF',
#   'prefix_long[-1]': 'wiede',
#   'prefix_long[-2]': 'aber',
#   'prefix_long[0]': 'als',
#   'prefix_long[1]': 'Lehre',
#   'prefix_long[2]': 'arbei',
#   'prefix_short[-1]': 'wie',
#   'prefix_short[-2]': 'abe',
#   'prefix_short[0]': 'als',
#   'prefix_short[1]': 'Leh',
#   'prefix_short[2]': 'arb',
#   'rank[0]': '11',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'eder',
#   'suffix_long[-1]|suffix_long[0]': 'eder|als',
#   'suffix_long[-2]': 'aber',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'aber|eder|als',
#   'suffix_long[0]': 'als',
#   'suffix_long[0]|suffix_long[1]': 'als|hrer',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'als|hrer|iten',
#   'suffix_long[1]': 'hrer',
#   'suffix_long[2]': 'iten',
#   'suffix_short[-1]': 'er',
#   'suffix_short[-1]|suffix_short[0]': 'er|ls',
#   'suffix_short[-2]': 'er',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'er|er|ls',
#   'suffix_short[0]': 'ls',
#   'suffix_short[0]|suffix_short[1]': 'ls|er',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'ls|er|en',
#   'suffix_short[1]': 'er',
#   'suffix_short[2]': 'en',
#   'w[-1]': 'wieder',
#   'w[-1]|w[0]': 'wieder|als',
#   'w[-2]': 'aber',
#   'w[0]': 'als',
#   'w[0]|w[1]': 'als|Lehrer',
#   'w[1]': 'Lehrer',
#   'w[2]': 'arbeiten',
#   'w_lower[-1]': 'wieder',
#   'w_lower[-2]': 'aber',
#   'w_lower[0]': 'als',
#   'w_lower[1]': 'lehrer',
#   'w_lower[2]': 'arbeiten'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPersonDic[2]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isInPlaceDic[2]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'True',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'als',
#   'lemma[0]': 'Lehrer',
#   'lemma[1]': 'arbeiten',
#   'pos[-1]': 'KOKOM',
#   'pos[-1]|pos[0]': 'KOKOM|NN',
#   'pos[-1]|pos[0]|pos[1]': 'KOKOM|NN|VVINF',
#   'pos[-2]': 'ADV',
#   'pos[-2]|pos[-1]': 'ADV|KOKOM',
#   'pos[-2]|pos[-1]|pos[0]': 'ADV|KOKOM|NN',
#   'pos[0]': 'NN',
#   'pos[0]|pos[1]': 'NN|VVINF',
#   'pos[0]|pos[1]|pos[2]': 'NN|VVINF|$.',
#   'pos[1]': 'VVINF',
#   'pos[1]|pos[2]': 'VVINF|$.',
#   'pos[2]': '$.',
#   'prefix_long[-1]': 'als',
#   'prefix_long[-2]': 'wiede',
#   'prefix_long[0]': 'Lehre',
#   'prefix_long[1]': 'arbei',
#   'prefix_long[2]': '.',
#   'prefix_short[-1]': 'als',
#   'prefix_short[-2]': 'wie',
#   'prefix_short[0]': 'Leh',
#   'prefix_short[1]': 'arb',
#   'prefix_short[2]': '.',
#   'rank[0]': '12',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'als',
#   'suffix_long[-1]|suffix_long[0]': 'als|hrer',
#   'suffix_long[-2]': 'eder',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'eder|als|hrer',
#   'suffix_long[0]': 'hrer',
#   'suffix_long[0]|suffix_long[1]': 'hrer|iten',
#   'suffix_long[0]|suffix_long[1]|suffix_long[2]': 'hrer|iten|.',
#   'suffix_long[1]': 'iten',
#   'suffix_long[2]': '.',
#   'suffix_short[-1]': 'ls',
#   'suffix_short[-1]|suffix_short[0]': 'ls|er',
#   'suffix_short[-2]': 'er',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'er|ls|er',
#   'suffix_short[0]': 'er',
#   'suffix_short[0]|suffix_short[1]': 'er|en',
#   'suffix_short[0]|suffix_short[1]|suffix_short[2]': 'er|en|.',
#   'suffix_short[1]': 'en',
#   'suffix_short[2]': '.',
#   'w[-1]': 'als',
#   'w[-1]|w[0]': 'als|Lehrer',
#   'w[-2]': 'wieder',
#   'w[0]': 'Lehrer',
#   'w[0]|w[1]': 'Lehrer|arbeiten',
#   'w[1]': 'arbeiten',
#   'w[2]': '.',
#   'w_lower[-1]': 'als',
#   'w_lower[-2]': 'wieder',
#   'w_lower[0]': 'lehrer',
#   'w_lower[1]': 'arbeiten',
#   'w_lower[2]': '.'},
#  {'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'endsWithDigit[1]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'hasDigit[1]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isDigit[1]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPersonDic[1]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isInPlaceDic[1]': 'False',
#   'isTitle[-1]': 'True',
#   'isTitle[0]': 'False',
#   'isTitle[1]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'isUpper[1]': 'False',
#   'lemma[-1]': 'Lehrer',
#   'lemma[0]': 'arbeiten',
#   'lemma[1]': '.',
#   'pos[-1]': 'NN',
#   'pos[-1]|pos[0]': 'NN|VVINF',
#   'pos[-1]|pos[0]|pos[1]': 'NN|VVINF|$.',
#   'pos[-2]': 'KOKOM',
#   'pos[-2]|pos[-1]': 'KOKOM|NN',
#   'pos[-2]|pos[-1]|pos[0]': 'KOKOM|NN|VVINF',
#   'pos[0]': 'VVINF',
#   'pos[0]|pos[1]': 'VVINF|$.',
#   'pos[1]': '$.',
#   'prefix_long[-1]': 'Lehre',
#   'prefix_long[-2]': 'als',
#   'prefix_long[0]': 'arbei',
#   'prefix_long[1]': '.',
#   'prefix_short[-1]': 'Leh',
#   'prefix_short[-2]': 'als',
#   'prefix_short[0]': 'arb',
#   'prefix_short[1]': '.',
#   'rank[0]': '13',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'hrer',
#   'suffix_long[-1]|suffix_long[0]': 'hrer|iten',
#   'suffix_long[-2]': 'als',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'als|hrer|iten',
#   'suffix_long[0]': 'iten',
#   'suffix_long[0]|suffix_long[1]': 'iten|.',
#   'suffix_long[1]': '.',
#   'suffix_short[-1]': 'er',
#   'suffix_short[-1]|suffix_short[0]': 'er|en',
#   'suffix_short[-2]': 'ls',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'ls|er|en',
#   'suffix_short[0]': 'en',
#   'suffix_short[0]|suffix_short[1]': 'en|.',
#   'suffix_short[1]': '.',
#   'w[-1]': 'Lehrer',
#   'w[-1]|w[0]': 'Lehrer|arbeiten',
#   'w[-2]': 'als',
#   'w[0]': 'arbeiten',
#   'w[0]|w[1]': 'arbeiten|.',
#   'w[1]': '.',
#   'w_lower[-1]': 'lehrer',
#   'w_lower[-2]': 'als',
#   'w_lower[0]': 'arbeiten',
#   'w_lower[1]': '.'},
#  {'EOS': 'True',
#   'endsWithDigit[-1]': 'False',
#   'endsWithDigit[0]': 'False',
#   'hasDigit[-1]': 'False',
#   'hasDigit[0]': 'False',
#   'isDigit[-1]': 'False',
#   'isDigit[0]': 'False',
#   'isInPersonDic[-1]': 'False',
#   'isInPersonDic[-2]': 'False',
#   'isInPersonDic[0]': 'False',
#   'isInPlaceDic[-1]': 'False',
#   'isInPlaceDic[-2]': 'False',
#   'isInPlaceDic[0]': 'False',
#   'isTitle[-1]': 'False',
#   'isTitle[0]': 'False',
#   'isUpper[-1]': 'False',
#   'isUpper[0]': 'False',
#   'lemma[-1]': 'arbeiten',
#   'lemma[0]': '.',
#   'pos[-1]': 'VVINF',
#   'pos[-1]|pos[0]': 'VVINF|$.',
#   'pos[-2]': 'NN',
#   'pos[-2]|pos[-1]': 'NN|VVINF',
#   'pos[-2]|pos[-1]|pos[0]': 'NN|VVINF|$.',
#   'pos[0]': '$.',
#   'prefix_long[-1]': 'arbei',
#   'prefix_long[-2]': 'Lehre',
#   'prefix_long[0]': '.',
#   'prefix_short[-1]': 'arb',
#   'prefix_short[-2]': 'Leh',
#   'prefix_short[0]': '.',
#   'rank[0]': '14',
#   'sent_rank[0]': '0',
#   'suffix_long[-1]': 'iten',
#   'suffix_long[-1]|suffix_long[0]': 'iten|.',
#   'suffix_long[-2]': 'hrer',
#   'suffix_long[-2]|suffix_long[-1]|suffix_long[0]': 'hrer|iten|.',
#   'suffix_long[0]': '.',
#   'suffix_short[-1]': 'en',
#   'suffix_short[-1]|suffix_short[0]': 'en|.',
#   'suffix_short[-2]': 'er',
#   'suffix_short[-2]|suffix_short[-1]|suffix_short[0]': 'er|en|.',
#   'suffix_short[0]': '.',
#   'w[-1]': 'arbeiten',
#   'w[-1]|w[0]': 'arbeiten|.',
#   'w[-2]': 'Lehrer',
#   'w[0]': '.',
#   'w_lower[-1]': 'arbeiten',
#   'w_lower[-2]': 'lehrer',
#   'w_lower[0]': '.'}]

# %% [markdown]
# # Annotate

# %%
y_pred = crf.predict(X_anno)

# %% [markdown]
# It's done! Now we just package everything together

# %%
annotation = []
for s, p in zip(tagged_sents, y_pred):
    anno_sent = []
    for tok_sent, tok_pred in zip(s, p):
        anno_sent.append(tuple(list(tok_sent[:-1]) + [tok_pred]))
    annotation.append(anno_sent)

# %% [markdown]
# **Et voillà...**

# %%
annotation[0]
# Out:
# [('1847', 'CARD', '@card@', '_', 'O'),
#  ('kehrte', 'VVFIN', 'kehren', '_', 'O'),
#  ('Mommsen', 'NN', '<unknown>', '_', 'B-PERmentioned'),
#  ('nach', 'APPR', 'nach', '_', 'O'),
#  ('Deutschland', 'NE', 'Deutschland', '_', 'B-PLACEmentioned'),
#  ('zurück', 'PTKVZ', 'zurück', '_', 'O'),
#  (',', '$,', ',', '_', 'O'),
#  ('musste', 'VMFIN', 'müssen', '_', 'O'),
#  ('vorerst', 'ADV', 'vorerst', '_', 'O'),
#  ('aber', 'ADV', 'aber', '_', 'O'),
#  ('wieder', 'ADV', 'wieder', '_', 'O'),
#  ('als', 'KOKOM', 'als', '_', 'O'),
#  ('Lehrer', 'NN', 'Lehrer', '_', 'O'),
#  ('arbeiten', 'VVINF', 'arbeiten', '_', 'O'),
#  ('.', '$.', '.', '_', 'O')]
